# %%
# 1) Add the current date to the text file today.txt as a string. 
import datetime

with open('today.txt','w') as f:
    date = datetime.datetime.now().strftime("%d %B %Y")
    f.write(date)

# %%
# 2) Read the text file today.txt into the string today_string

s = open('today.txt','r')
today_string = s.read()
today_string

# %%
# 3) Parse the date from today_string. 
datetime.datetime.strptime(today_string,'%d %B %Y')

# %%
# 4) List the files in your current directory 
import os
os.listdir()
# os.getcwd()

# %%
# 5) Create a list of all of the files in your parent directory (minimum five files should be available).
# os.listdir('C:\\Users\\priti')
list(filter(os.path.isfile, os.listdir('C:\\Users\\priti\\ineuron')))

# %%
# 6) Use multiprocessing to create three separate processes. Make each one wait a random number 
# of seconds between one and five, print the current time, and then exit. 
import multiprocessing,time,datetime
import zoo 

# def process1():
#     t1 = random.randint(1,5)
#     print("Waiting for "+str(t1)+" seconds")
#     time.sleep(t1)
#     print(datetime.datetime.now())


start = time.time()
process1 = zoo.process1()
process2 = zoo.process1()
process3 = zoo.process1()

print(datetime.datetime.now())
if __name__=="__main__":
    
    
    
    p1 = multiprocessing.Process(target=process1)
    p2 = multiprocessing.Process(target=process2)
    p3 = multiprocessing.Process(target=process3)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

end = time.time()
    

print("It takes " +str(end-start)+" seconds")
# Out:
# Waiting for 4 seconds
# 2022-03-28 19:23:36.604154
# Waiting for 4 seconds
# 2022-03-28 19:23:40.613756
# Waiting for 1 seconds
# 2022-03-28 19:23:41.623822
# 2022-03-28 19:23:41.623822
# It takes 9.33227825164795 seconds

# %%
# 7) Create a date object of your day of birth.
dob = '01012001'
import datetime
datetime.datetime.strptime(dob,"%d%m%Y").date()

# %%
# 8) What day of the week was your day of birth? 
import calendar
calendar.day_name[datetime.datetime.strptime(dob,"%d%m%Y").weekday()]

# %%
# 9) When will you be (or when were you) 10,000 days old? Page 1 of 1
import datetime

start_date = datetime.datetime(year=2008, month=5, day=19)

end_date = start_date + datetime.timedelta(days=10000)

print(end_date.date())
