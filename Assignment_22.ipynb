# %%
# 1) What is the result of the code, and explain? 
X = 'iNeuron' 
def func(): 
    print(X)
func() 

# Result - iNeuron
# On line 4, It looks for X in the local scope and then in the global scope and find it to print it.
# Out:
# iNeuron

# %%
    
#     2. What is the result of the code, and explain? 
X = 'iNeuron'
def func(): 
    X = 'NI!'
func() 
print(X) 

# Result - iNeuron
# Variable on line 5 is destroyed when func() finishes executing so X remains what it was on line 3
# Out:
# iNeuron

# %%
      
# 3. What does this code print, and why? 
X = 'iNeuron' 
def func(): 
    X = 'NI' 
    print(X)
func() 
print(X) 

# Result - 
# - NI
# - iNeuron
# # x is NI in the local scope so func() prints NI. print(X) prints 'iNeuron' cause local varibale on line 5 is destroyed when func() ends.
# Out:
# NI
# iNeuron

# %%
    
# 4. What output does this code produce? Why? Page 1 of 3
X = 'iNeuron'
def func(): 
    global X 

    X = 'NI'
  
func() 
print(X)

# Result - NI
# Line 5, when We use global keyword, global variable on line 3 is referred inside the function. Chnages made within function apply outside function as well.
# Out:
# NI

# %%
    
# 5. What about this code—what’s the output, and why? 
X = 'iNeuron'
def func(): 
    X = 'NI' 
    def nested(): 
        print("Inside nested: " + (X)) 
    nested() 
func()
X 

# Result 
# - Inside nested: NI
# - iNeuron
# This is a closure where the nested function refers X which is in the enclosing scope/function and can access that.
# The criteria that must be met to create closure in Python are summarized in the following points.

    # We must have a nested function (function inside a function).
    # The nested function must refer to a value defined in the enclosing function.
    # The enclosing function must return the nested function.
# Out:
# Inside nested: NI
# 'iNeuron'

# %%
      
# 6. How about this code: what is its output in Python 3, and explain? 
def func(): 
    X = 'NI' 
    def nested(): 
        nonlocal X 
        X = 'Spam' 
    nested() 
    print(X) 
func()
# - Result: Spam
#Cause of line no 6, X referred is not from the local scope so it refers to 'NI' and then, its changed to 'spam' and printed.
# Out:
# Spam
