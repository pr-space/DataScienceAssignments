# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# 6
#
# 'hello',-87.8, 6 are values. -,/ are mathematical expressions.
#
# 2. What is the difference between string and variable?
#
# A string is a data type which encloses text in quotation marks. It can be a number or alphabets like "hello123" or "123".
#
# A variable is used to store specific values within the program. It has an assigned data type and value. A variable can be a string or any other data type.
# eg: In x=5, x is the variable storing an int data type with the value of 5.
#
#
# 3. Describe three different data types.
#
# Int data type : It is a numeric data type used to store numbers without a fractional component like 43,2,1,-1.
#
# Bool : It represents the value of True and False. At times, T = 1 and F=0.
#
# Array: It is a ordered list of elements. eg: [1,2,"three"]
#
# 4. What is an expression made up of? What do all expressions do?
#
# An expression is made up of operators and operands and all expressions tend to evaluate to a single value.
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# A statement is an action or a command that does something. Here, the value of 10 is assigned to the variable spam.
# An expression is operands and operators yielding something. eg: spam = 10+2 which evaluates to a single value of 12.

# %%
# 6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
bacon
# Value of bacon remains 22
# Out:
# 22

# %%
# 7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3
# Both the answers are 'spamspamspam'.
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Variables must start with a alphabet or an underscore so thats why 100 is invalid while eggs is a valid name.
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# The int() , float() , and str( ) functions will evaluate to the integer, floating-point number, and string versions of the value passed to them

# %%
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# The error is that 99 is an int which cannot be concatenated with a string.
# By typecasting 99 to str, we can fix the error i.e.
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
