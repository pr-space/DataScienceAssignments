# %% [markdown]
# 1) What is the concept of an abstract superclass?
#
#
#
# 2) What happens when a class statement's top level contains a basic assignment statement?
# > These variables defined are called class attributes or class level variables while variables defined inside constructors are called instance variables. When an instance of a class is created, there is a single copy of class attributes made which is distributed to all instances whereas each instance has its own copy of instance variables.
#
# 3) Why does a class need to manually call a superclass's __init__ method?
# > super() gives you access to attributes and methods of the superclass to the subclass.
#
#
# 4) How can you augment, instead of completely replacing, an inherited method?
#
#
#
# 5) How is the local scope of a class different from that of a function?
# > The variables inside a class are available to use outside a class. whereas the variables inside a function are destroyed once function is returned so that cannot be accessed outside a function.
