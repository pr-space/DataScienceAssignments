# %% [markdown]
# Q1) What is the purpose of Python's OOP?
# > Provides a clear program structure and a clean code
#
# > Facilitates easy maintenance and modification of existing code
#
# > Since the class is sharable, the code can be reused
#
# > Since the class is sharable, the code can be reused and many other such Advantages.
#
#
#
# Q2) Where does an inheritance search look for an attribute?
#
# >  by looking in object, then in all classes above it, from bottom to top and left to right.
#
# Q3) How do you distinguish between a class object and an instance object?
# > An instance is a specific realization of any object. An object may be varied in a number of ways. Each realized variation of that object is an instance.
#
# > A class is a user-defined blueprint or prototype from which objects are created. Classes provide a means of bundling data and functionality together. Creating a new class creates a class object.
#
# > In the example below, when class course is written, a class object is created whereas the instance object is created when an object is realised by naming the class and adding parenthesis to it.
#
# ```
# class course:
#     def a():
#          print("This is a")
#
# instanceObj = course()
# ```
#
#
# Q4) What makes the first argument in a class’s method function special?
#
# > The self is used to represent the instance of the class. With this keyword, you can access the attributes and methods of the class in python. It binds the attributes with the given arguments
#
# Q5) What is the purpose of the __init__ method?
# > The __init__ method lets the class initialize the object's attributes and serves no other purpose. It is only used within classes.
#
#
# Q6) What is the process for creating a class instance?
#
# >Create a class
#
# > call the class using class name and assign it to a variable (object variable)
#
# > pass in whatever arguments its init method accepts
#
# Q7) What is the process for creating a class?
#
# > process to create class
#
# - class definition starts with keyword class
# - follwed by classname and ':'
# - class will have doc string
# - class should have at least one statements.
#
# Q8) How would you define the superclasses of a class?
#
# > The class from which a class inherits is called the parent or superclass
