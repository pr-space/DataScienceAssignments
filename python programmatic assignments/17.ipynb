# %%
# 1)

def evenly_divisible(a,b,c):
    sum = 0
    for i in range(a,b+1):
        if i%c==0:
            sum += i
    return sum

evenly_divisible(1,10,2)
# Out:
# 30

# %%
# 2)

def correct_signs(s):
    if eval(s):
        return True
    return False
correct_signs("113>13>3")
# Out:
# True

# %%
# 3)

def replace_vowels(test_str,K):
   
    vowels = 'AEIOUaeiou'
 
    # iterating to check vowels in string
    for ele in vowels:
 
        # replacing vowel with the specified character
        test_str = test_str.replace(ele, K)
 
    return test_str

replace_vowels("aaaaa","$")
# Out:
# '$$$$$'

# %%
# 4)

def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
    
factorial(0)
# Out:
# 1

# %%
# 5)

def hamming_distance(word1,word2):
    count = 0
    for i in range(0,len(word1)):
        if word1[i]!=word2[i]:
            count +=1
    return count

hamming_distance("word123","word234")
# Out:
# 3
